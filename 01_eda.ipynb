# %%
import sys
import os

# %%
sys.path.append(os.path.abspath('..'))
from src.data_loader import load_train_data

# %%
train_df = load_train_data()
# Out:
# Loading training data
# (20000, 11)

# %%
display(train_df.head())
# Out:
#    Age        Income  CreditScore    LoanAmount  EmploymentYears  \
# 0   59  16785.977212        604.0  19416.230574                3
# 1   49  62263.017648        613.0  16902.153253               33
# 2   35  62414.862646          NaN  21639.847552                1
# 3   63  62653.254368        363.0  17216.445061                3
# 4   28  54601.849437        607.0  22955.590991               22
#
#    NumDependents  DebtToIncome  EducationLevel FavoriteColor      Hobby  \
# 0              2      0.912395               3         Green  Traveling
# 1              2      0.455917               1          Blue  Traveling
# 2              1      0.817570               3          Blue  Traveling
# 3              0      0.519046               3         Green    Reading
# 4              4      0.197581               1        Yellow    Reading
#
#    Default
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
